# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('E:\\Book3.xlsx')
df
# Out:
#           ID Spending ability  Personality Type  \
# 0     FC0001              Low               100
# 1     FC0002           Medium                70
# 2     FC0003             High               100
# 3     FC0004              Low                80
# 4     FC0005              Low               100
# ...      ...              ...               ...
# 2995  FC2996             High                20
# 2996  FC2997           Medium                30
# 2997  FC2998             High               100
# 2998  FC2999             High                10
# 2999  FC3000              Low                80
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 0                                                    38
# 1                                                    62
# 2                                                    54
# 3                                                    76
# 4                                                    44
# ...

# %%
dfx = df

# %%
df=dfx.sort_values(by ='sum', ascending=True).head(1800)

# %%
df1= df[df['Spending ability']!='Low']
df1
# Out:
#           ID Spending ability  Personality Type  \
# 2615  FC2616             High                90
# 153   FC0154           Medium                40
# 1529  FC1530           Medium                30
# 430   FC0431             High               100
# 2136  FC2137             High                40
# ...      ...              ...               ...
# 2057  FC2058           Medium                80
# 1655  FC1656           Medium                30
# 1089  FC1090           Medium                90
# 1090  FC1091           Medium                70
# 1329  FC1330             High                90
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 2615                                                 46
# 153                                                  54
# 1529                                                 35
# 430                                                  76
# 2136                                                 47
# ...

# %%
df2 = df1[(df1['Winniability']>=50) & (df['Personality Type']>=40)]
# Out:
# C:\Users\nites\AppData\Local\Temp/ipykernel_10144/1660283198.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df1[(df1['Winniability']>=50) & (df['Personality Type']>=40)]

# %%
df2
# Out:
#           ID Spending ability  Personality Type  \
# 2615  FC2616             High                90
# 153   FC0154           Medium                40
# 2136  FC2137             High                40
# 598   FC0599             High                70
# 1907  FC1908             High               100
# ...      ...              ...               ...
# 2991  FC2992             High                90
# 1411  FC1412           Medium                60
# 2726  FC2727           Medium                70
# 2407  FC2408             High                70
# 2057  FC2058           Medium                80
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 2615                                                 46
# 153                                                  54
# 2136                                                 47
# 598                                                  76
# 1907                                                 71
# ...

# %%
dfp = df2[df2['Distance Factor with respect to hostel location (out of 10)']<=60]

# %%
dfp
# Out:
#           ID Spending ability  Personality Type  \
# 2615  FC2616             High                90
# 2136  FC2137             High                40
# 1907  FC1908             High               100
# 1649  FC1650           Medium               100
# 2980  FC2981           Medium                60
# ...      ...              ...               ...
# 246   FC0247           Medium                50
# 1020  FC1021           Medium                40
# 2991  FC2992             High                90
# 2407  FC2408             High                70
# 2057  FC2058           Medium                80
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 2615                                                 46
# 2136                                                 47
# 1907                                                 71
# 1649                                                 44
# 2980                                                 21
# ...

# %%
dfp= dfp[dfp['Potential to shift from preference 1(in terms of quality for the same product)(%)']>30]

# %%
dfp = dfp[dfp['Potential to shift from preference 1(in terms of price for the same product) (%)']>40]

# %%
dfp
# Out:
#           ID Spending ability  Personality Type  \
# 2136  FC2137             High                40
# 1907  FC1908             High               100
# 1649  FC1650           Medium               100
# 96    FC0097             High                70
# 1849  FC1850           Medium                70
# ...      ...              ...               ...
# 785   FC0786           Medium                50
# 2012  FC2013             High                60
# 1051  FC1052           Medium                40
# 1020  FC1021           Medium                40
# 2057  FC2058           Medium                80
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 2136                                                 47
# 1907                                                 71
# 1649                                                 44
# 96                                                   73
# 1849                                                 60
# ...

# %%
dfp
# Out:
#           ID Spending ability  Personality Type  \
# 2136  FC2137             High                40
# 1907  FC1908             High               100
# 1649  FC1650           Medium               100
# 96    FC0097             High                70
# 1849  FC1850           Medium                70
# ...      ...              ...               ...
# 785   FC0786           Medium                50
# 2012  FC2013             High                60
# 1051  FC1052           Medium                40
# 1020  FC1021           Medium                40
# 2057  FC2058           Medium                80
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 2136                                                 47
# 1907                                                 71
# 1649                                                 44
# 96                                                   73
# 1849                                                 60
# ...

# %%
dfp[dfp['Spending ability']=='High']
# Out:
#           ID Spending ability  Personality Type  \
# 2136  FC2137             High                40
# 1907  FC1908             High               100
# 96    FC0097             High                70
# 315   FC0316             High                90
# 870   FC0871             High                40
# ...      ...              ...               ...
# 2430  FC2431             High                60
# 2709  FC2710             High               100
# 237   FC0238             High                70
# 2835  FC2836             High                50
# 2012  FC2013             High                60
#
#       Potential to shift from preference 1(in terms of price for the same product) (%)  \
# 2136                                                 47
# 1907                                                 71
# 96                                                   73
# 315                                                  78
# 870                                                  42
# ...
